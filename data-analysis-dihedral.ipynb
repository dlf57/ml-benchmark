# %%
import pandas as pd

# %%
dft = pd.read_csv('data/dft-data-dihedral.csv')
ani2 = pd.read_csv('data/ani2-dihedral-results.csv')
band = pd.read_csv('data/BAND-dihedral-results.csv')
# fchl = pd.read_csv('data/fchl-results.csv')
# bobrfr = pd.read_csv('data/bob-rfr.csv')
# bobkrr = pd.read_csv('data/bob-krr.csv')
# bobbrr = pd.read_csv('data/bob-brr.csv')
mmff = pd.read_csv('data/mmff-dihedral-results.csv')
gaff = pd.read_csv('data/gaff-dihedral-results.csv')

# %%
df = pd.merge(dft, ani2, on=['name', 'phi', 'psi', 'theta'])
df = pd.merge(df, band, on=['name', 'phi', 'psi', 'theta'])
# df = df.merge(bobrfr, on=['name', 'point'])
# df = pd.merge(df, bobkrr, on=['name', 'point'])
# df = df.merge(bobbrr, on=['name', 'point'])
# df = df.merge(fchl, on=['name', 'point'])
df = df.merge(mmff, on=['name', 'phi', 'psi', 'theta'])
df = df.merge(gaff, on=['name', 'phi', 'psi', 'theta'])
df
# Out:
#                 name    phi    psi  theta        energy   ani2_energy  \
# 0            ala-ala -100.0 -100.0    NaN -15534.900658 -15535.196502
# 1            ala-ala -100.0 -120.0    NaN -15534.739239 -15534.996001
# 2            ala-ala -100.0 -140.0    NaN -15531.340037 -15531.719654
# 3            ala-ala -100.0 -160.0    NaN -15535.108399 -15535.279657
# 4            ala-ala -100.0 -180.0    NaN -15534.326386 -15534.686115
# ...              ...    ...    ...    ...           ...           ...
# 1122  biphenyl-twist    NaN    NaN  -60.0 -12603.389102 -12603.597429
# 1123  biphenyl-twist    NaN    NaN  -45.0 -12603.424953 -12603.627648
# 1124  biphenyl-twist    NaN    NaN  -30.0 -12603.407128 -12603.590452
# 1125  biphenyl-twist    NaN    NaN  -15.0 -12603.328661 -12603.503928
# 1126  biphenyl-twist    NaN    NaN -180.0 -12603.271087 -12603.446614
#
#       BAND_energy  mmff_energy  gaff_energy
# 0    -2304.801270    52.060968    12.837149
# 1    -2322.531738    53.046763    91.990525
# 2    -2308.384766   105.857367  2060.684305
# 3    -2303.422119    51.707037    14.430291
# 4    -2294.462646    64.615650   186.882373
# ...           ...          ...          ...
# 1122 -2628.438477    40.320776    58.376349
# 1123 -2627.586426    40.710487    53.411610
# 1124 -2627.745361    42.685406    53.370726
# 1125 -2628.681152    46.569398    66.710071
# 1126 -2632.671387    49.276555    83.096448
#
# [1127 rows x 9 columns]

# %% [markdown]
# ### Convert BoB energies to eV

# %%
df['fchl_energy'] = df['fchl_energy'].multiply(27.2114)
df['bobrfr_energy'] = df['bobrfr_energy'].multiply(27.2114)
df['bobkrr_energy'] = df['bobkrr_energy'].multiply(27.2114)
df['bobbrr_energy'] = df['bobbrr_energy'].multiply(27.2114)
df
# Out:
#        name  point bond  length       energy  ani2_energy  BAND_energy  \
# 0    C6H6-C      1   CC  0.9846 -6259.129633 -6260.302569 -1012.032471
# 1    C6H6-C      2   CC  1.0846 -6290.919938 -6289.022412 -1110.447632
# 2    C6H6-C      3   CC  1.1846 -6307.793560 -6307.997541 -1222.968384
# 3    C6H6-C      4   CC  1.2846 -6315.569917 -6315.675317 -1319.632568
# 4    C6H6-C      5   CC  1.3846 -6317.796290 -6317.909650 -1372.762085
# ..      ...    ...  ...     ...          ...          ...          ...
# 580     NH3     41   NH  4.6126 -1512.751874 -1529.949810          NaN
# 581     NH3     42   NH  4.7126 -1512.665388 -1530.330988          NaN
# 582     NH3     43   NH  4.8126 -1512.585553 -1530.534665          NaN
# 583     NH3     44   NH  4.9126 -1512.511668 -1530.596923          NaN
# 584     NH3     45   NH  5.0126 -1512.443002 -1530.605845          NaN
#
#      bobrfr_energy  bobkrr_energy  bobbrr_energy  fchl_energy    mmff_energy  \
# 0     -6325.684144   -6320.096921   -6318.324263 -6120.945190     967.973391
# 1     -6322.702227   -6320.702055   -6317.652787 -6251.795173     458.862047
# 2     -6316.979348   -6320.226571   -6317.045847 -6298.134416     181.276942
# 3     -6316.373403   -6319.117238   -6316.485922 -6314.011504      53.067576
# 4     -6316.399086   -6317.632463   -6315.967471 -6317.577834      16.575675
# ..             ...            ...            ...          ...            ...
# 580   -3439.747345   -1539.379564   -1535.584490 -1525.506390  433309.054340
# 581   -3439.747345   -1539.344504   -1535.574721 -1525.499332  486442.285243
# 582   -3439.747345   -1539.307991   -1535.564543 -1525.498990  544320.128547
# 583   -3439.747345   -1539.274800   -1535.555303 -1525.507894  607249.867544
# 584   -3439.747345   -1539.242855   -1535.546472 -1525.486100  675505.673010
#
#       gaff_energy
# 0     3420.359315
# 1     1548.954508
# 2      641.700866
# 3      178.685005
# 4       19.456137
# ..            ...
# 580  63960.737052
# 581  67569.069690
# 582  71275.424166
# 583  75081.747139
# 584  78987.295977
#
# [585 rows x 13 columns]

# %%
df.to_csv('data/data-all-dihedral.csv', index=False)

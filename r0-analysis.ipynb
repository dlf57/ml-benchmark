# %% [markdown]
# Find r<sub>0

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/data-all.csv')
df = df.fillna(np.nan)
df
# Out:
#        name  point bond  length       energy  ani2_energy  BAND_energy  \
# 0    C6H6-C      1   CC  0.9846 -6259.129633 -6260.302569 -1012.032471
# 1    C6H6-C      2   CC  1.0846 -6290.919938 -6289.022412 -1110.447632
# 2    C6H6-C      3   CC  1.1846 -6307.793560 -6307.997541 -1222.968384
# 3    C6H6-C      4   CC  1.2846 -6315.569917 -6315.675317 -1319.632568
# 4    C6H6-C      5   CC  1.3846 -6317.796290 -6317.909650 -1372.762085
# ..      ...    ...  ...     ...          ...          ...          ...
# 580     NH3     41   NH  4.6126 -1512.751874 -1529.949810          NaN
# 581     NH3     42   NH  4.7126 -1512.665388 -1530.330988          NaN
# 582     NH3     43   NH  4.8126 -1512.585553 -1530.534665          NaN
# 583     NH3     44   NH  4.9126 -1512.511668 -1530.596923          NaN
# 584     NH3     45   NH  5.0126 -1512.443002 -1530.605845          NaN
#
#      bobrfr_energy  bobkrr_energy  bobbrr_energy  fchl_energy    mmff_energy  \
# 0     -6325.684144   -6320.096921   -6318.324263 -6120.945190     967.973391
# 1     -6322.702227   -6320.702055   -6317.652787 -6251.795173     458.862047
# 2     -6316.979348   -6320.226571   -6317.045847 -6298.134416     181.276942
# 3     -6316.373403   -6319.117238   -6316.485922 -6314.011504      53.067576
# 4     -6316.399086   -6317.632463   -6315.967471 -6317.577834      16.575675
# ..             ...            ...            ...          ...            ...
# 580   -3439.747345   -1539.379564   -1535.584490 -1525.506390  433309.054340
# 581   -3439.747345   -1539.344504   -1535.574721 -1525.499332  486442.285243
# 582   -3439.747345   -1539.307991   -1535.564543 -1525.498990  544320.128547
# 583   -3439.747345   -1539.274800   -1535.555303 -1525.507894  607249.867544
# 584   -3439.747345   -1539.242855   -1535.546472 -1525.486100  675505.673010
#
#       gaff_energy
# 0     3420.359315
# 1     1548.954508
# 2      641.700866
# 3      178.685005
# 4       19.456137
# ..            ...
# 580  63960.737052
# 581  67569.069690
# 582  71275.424166
# 583  75081.747139
# 584  78987.295977
#
# [585 rows x 13 columns]

# %%
names = np.unique(df['name'])
names
# Out:
# array(['C6H6-C', 'C6H6-H', 'CH3OH', 'CH4', 'CO', 'H2', 'H2CCH2', 'H2O',
#        'HCCH', 'HCN', 'HF', 'N2', 'NH3'], dtype=object)

# %%
r0 = []
for name in names:
    ndf = df[df['name'] == name]

    min_e = min(ndf['energy'])
    min_a = min(ndf['ani2_energy'])
    if name == 'CO':
        # CO goes down after 2.5 angstroms 
        min_a = min(ndf['ani2_energy'][:15])
    min_gaff = min(ndf['gaff_energy'][:10])
    if name != 'HF':
        min_b = min(ndf['BAND_energy'].dropna())
        min_fchl = min(ndf['fchl_energy'])
        min_bob = min(ndf['bobrfr_energy'])
        min_bobk = min(ndf['bobkrr_energy'])
        min_bobb = min(ndf['bobbrr_energy'])
        min_mmff = min(ndf['mmff_energy'][:9])
    else:
        min_b = 'nan'
        min_fchl = 'nan'
        min_bob = 'nan'
        min_bobk = 'nan'
        min_bobb = 'nan'
        min_mmff = min(ndf['mmff_energy'][:8])

    pt_e = ndf.loc[df['energy'] == min_e, 'point'].iloc[0]
    pt_a = ndf.loc[df['ani2_energy'] == min_a, 'point'].iloc[0]
    pt_mmff = ndf.loc[df['mmff_energy'] == min_mmff, 'point'].iloc[0]
    pt_gaff = ndf.loc[df['gaff_energy'] == min_gaff, 'point'].iloc[0]
    if name != 'HF':
        pt_b = ndf.loc[df['BAND_energy'] == min_b, 'point'].iloc[0]
        pt_fchl = ndf.loc[df['fchl_energy'] == min_fchl, 'point'].iloc[0]
        pt_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'point'].iloc[0]
        pt_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'point'].iloc[0]
        pt_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'point'].iloc[0]
    else:
        pt_b = 'nan'
        pt_fchl = 'nan'
        pt_bob = 'nan'
        pt_bobk = 'nan'
        pt_bobb = 'nan'

    l_e = ndf.loc[df['energy'] == min_e, 'length'].iloc[0]
    l_a = ndf.loc[df['ani2_energy'] == min_a, 'length'].iloc[0]
    l_mmff = ndf.loc[df['mmff_energy'] == min_mmff, 'length'].iloc[0]
    l_gaff = ndf.loc[df['gaff_energy'] == min_gaff, 'length'].iloc[0]
    if name != 'HF':
        l_b = ndf.loc[df['BAND_energy'] == min_b, 'length'].iloc[0]
        l_fchl = ndf.loc[df['fchl_energy'] == min_fchl, 'length'].iloc[0]
        l_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'length'].iloc[0]
        l_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'length'].iloc[0]
        l_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'length'].iloc[0]
    else:
        l_b = 'nan'
        l_fchl = 'nan'
        l_bob = 'nan'
        l_bobk = 'nan'
        l_bobb = 'nan'
        
    d = {}
    d.update({'molecule': name})
    d.update({'point-dft': pt_e})
    d.update({'length-dft': l_e})
    d.update({'minE-dft': min_e})
    d.update({'point-ani2': pt_a})
    d.update({'length-ani2': l_a})
    d.update({'minE-ani2': min_a})
    d.update({'point-band': pt_b})
    d.update({'length-band': l_b})
    d.update({'minE-band': min_b})
    d.update({'point-fchl': pt_fchl})
    d.update({'length-fchl': l_fchl})
    d.update({'minE-fchl': min_fchl})
    d.update({'point-bobrfr': pt_bob})
    d.update({'length-bobrfr': l_bob})
    d.update({'minE-bobrfr': min_bob})
    d.update({'point-bobkrr': pt_bobk})
    d.update({'length-bobkrr': l_bobk})
    d.update({'minE-bobkrr': min_bobk})
    d.update({'point-bobbrr': pt_bobb})
    d.update({'length-bobbrr': l_bobb})
    d.update({'minE-bobbrr': min_bobb})
    d.update({'point-mmff': pt_mmff})
    d.update({'length-mmff': l_mmff})
    d.update({'minE-mmff': min_mmff})
    d.update({'point-gaff': pt_gaff})
    d.update({'length-gaff': l_gaff})
    d.update({'minE-gaff': min_gaff})
    r0.append(d)

# %%
rdf = pd.DataFrame(r0, columns=['molecule', 
                                'point-dft', 'length-dft', 'minE-dft', 
                                'point-ani2', 'length-ani2', 'minE-ani2', 
                                'point-band', 'length-band', 'minE-band',
                                'point-fchl', 'length-fchl', 'minE-fchl',
                                'point-bobrfr', 'length-bobrfr', 'minE-bobrfr',
                                'point-bobkrr', 'length-bobkrr', 'minE-bobkrr',
                                'point-bobbrr', 'length-bobbrr', 'minE-bobbrr',
                                'point-mmff', 'length-mmff', 'minE-mmff',
                                'point-gaff', 'length-gaff', 'minE-gaff'])
rdf
# Out:
#    molecule  point-dft  length-dft     minE-dft  point-ani2  length-ani2  \
# 0    C6H6-C          5     1.38460 -6317.796290           5      1.38460
# 1    C6H6-H          5     1.08049 -6317.796291           5      1.08049
# 2     CH3OH          5     1.40620 -3147.771121           5      1.40620
# 3       CH4          5     1.08220 -1102.023782           5      1.08220
# 4        CO          5     1.12710 -3082.492964           5      1.12710
# 5        H2          5     0.77660   -31.749980           5      0.77660
# 6    H2CCH2          5     1.31630 -2137.610367           5      1.31630
# 7       H2O          5     0.95920 -2078.579646           5      0.95920
# 8      HCCH          5     1.19370 -2103.310860           5      1.19370
# 9       HCN          5     1.13750 -2541.292611           5      1.13750
# 10       HF          5     0.93240 -2731.946285           5      0.93240
# 11       N2          5     1.09820 -2979.523223           5      1.09820
# 12      NH3          5     1.01260 -1538.210649           5      1.01260
#
#       minE-ani2 point-band length-band minE-band  ... minE-bobkrr  \
# 0  -6317.909650          5      1.3846  -1372.76  ...     -6320.7
# 1  -6317.909650          5     1.08049  -1372.76  ...    -6317.85
# 2  -3147.823690          5      1.4062  -506.988  ...    -3143.47
# 3  -1102.038219          5      1.0822  -418.106  ...    -1104.18
# 4  -3082.539701          1      0.7271  -179.053  ...    -3089.57
# 5    -30.731869          3      0.5769  -106.992  ...    -66.2559
# 6  -2137.645485          5      1.3163  -559.355  ...    -2137.21
# 7  -2078.624807          5      0.9592  -219.454  ...    -2087.04
# 8  -2103.355768          5      1.1937  -400.345  ...     -2102.4
# 9  -2541.349860          3      0.9375  -307.112  ...    -2550.72
# 10 -2731.988441        nan         nan       nan  ...         nan
# 11 -2979.606018          9      1.4982  -226.982  ...    -2978.59
# 12 -1538.241031          5      1.0126  -283.716  ...    -1545.25
#
#    point-bobbrr length-bobbrr minE-bobbrr point-mmff length-mmff   minE-mmff  \
# 0             1        0.9846    -6318.32          5     1.38460   16.575675
# 1            10       1.58057    -6316.44          5     1.08049   16.575675
# 2            20        2.9062    -3142.82          5     1.40620    1.077657
# 3            45        5.0822    -1103.03          5     1.08220    0.167136
# 4            45        5.1271    -3086.73          6     1.22710    0.823775
# 5            45         4.772    -23.9464          1     0.37710    0.000000
# 6             7        1.5163    -2134.66          5     1.31630    8.641677
# 7            45        4.9592    -2075.41          5     0.95920    0.232217
# 8            45        5.1937    -2104.25          5     1.19370  164.337949
# 9            45        5.1375    -2543.98          5     1.13750    0.650222
# 10          nan           nan         nan          5     0.93240    0.031521
# 11           45        5.0982    -2968.07          8     1.39820    0.116624
# 12            1        0.6126     -1538.7          5     1.01260    0.136011
#
#    point-gaff length-gaff    minE-gaff
# 0           5     1.38460    19.456137
# 1           5     1.08049    19.456137
# 2           5     1.40620    11.175286
# 3           5     1.08220     0.922327
# 4           6     1.22710     0.465586
# 5           8     1.07630     1.175842
# 6           5     1.31630     4.193630
# 7           6     1.05920     6.969755
# 8           5     1.19370  3643.998149
# 9           5     1.13750     0.183724
# 10          7     1.13240     2.197568
# 11          5     1.09820     3.404758
# 12          5     1.01260     0.190823
#
# [13 rows x 28 columns]

# %%
rdf.to_csv('data/r0.csv', index=False)

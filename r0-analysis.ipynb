# %% [markdown]
# Find r<sub>0

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/data-all.csv')
df = df.fillna(np.nan)
df
# Out:
#         name  point bond    length  ani2_energy       energy  BAND_energy  \
# 0    C6H6_CC      1   CC  1.124873  -231.508202 -6299.059051 -1191.119751
# 1    C6H6_CC      2   CC  1.144575  -231.630250 -6302.336406 -1207.077515
# 2    C6H6_CC      3   CC  1.166114  -231.737506 -6305.438418 -1223.121460
# 3    C6H6_CC      4   CC  1.189853  -231.834645 -6308.330531 -1249.354614
# 4    C6H6_CC      5   CC  1.216349  -231.928546 -6310.980175 -1282.178955
# ..       ...    ...  ...       ...          ...          ...          ...
# 580      NH3     41   NH  4.594305   -56.365524 -1518.240095          NaN
# 581      NH3     42   NH  4.696391   -56.368388 -1518.180197          NaN
# 582      NH3     43   NH  4.798596   -56.369650 -1518.117057          NaN
# 583      NH3     44   NH  4.900942   -56.369535 -1518.055211          NaN
# 584      NH3     45   NH  5.003033   -56.368896 -1518.001893          NaN
#
#      bobrfr_energy  bobkrr_energy  bobbrr_energy
# 0      -233.388959    -119.235042    -119.197742
# 1      -232.229854    -119.236169    -119.199174
# 2      -232.170149    -119.236978    -119.200471
# 3      -232.170145    -119.237526    -119.201941
# 4      -232.170281    -119.237799    -119.202765
# ..             ...            ...            ...
# 580     -58.869902     -56.495139     -56.350000
# 581     -58.869902     -56.495183     -56.349399
# 582     -58.869902     -56.495172     -56.348852
# 583     -58.869902     -56.495327     -56.348598
# 584     -58.869902     -56.495154     -56.347785
#
# [585 rows x 10 columns]

# %%
names = np.unique(df['name'])
names
# Out:
# array(['C6H6_CC', 'C6H6_CH', 'CH3OH', 'CH4', 'CO', 'H2', 'H2CCH2', 'H2O',
#        'HCCH', 'HCN', 'HF', 'N2', 'NH3'], dtype=object)

# %%
r0 = []
for name in names:
    ndf = df[df['name'] == name]

    min_e = min(ndf['energy'])
    min_a = min(ndf['ani2_energy'])
    if name != 'HF':
        min_b = min(ndf['BAND_energy'].dropna())
        min_bob = min(ndf['bobrfr_energy'])
        min_bobk = min(ndf['bobkrr_energy'])
        min_bobb = min(ndf['bobbrr_energy'])
    else:
        min_b = 'nan'
        min_bob = 'nan'
        min_bobk = 'nan'
        min_bobb = 'nan'

    pt_e = ndf.loc[df['energy'] == min_e, 'point'].iloc[0]
    pt_a = ndf.loc[df['ani2_energy'] == min_a, 'point'].iloc[0]
    if name != 'HF':
        pt_b = ndf.loc[df['BAND_energy'] == min_b, 'point'].iloc[0]
        pt_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'point'].iloc[0]
        pt_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'point'].iloc[0]
        pt_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'point'].iloc[0]
    else:
        pt_b = 'nan'
        pt_bob = 'nan'
        pt_bobk = 'nan'
        pt_bobb = 'nan'

    l_e = ndf.loc[df['energy'] == min_e, 'length'].iloc[0]
    l_a = ndf.loc[df['ani2_energy'] == min_a, 'length'].iloc[0]
    if name != 'HF':
        l_b = ndf.loc[df['BAND_energy'] == min_b, 'length'].iloc[0]
        l_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'length'].iloc[0]
        l_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'length'].iloc[0]
        l_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'length'].iloc[0]
    else:
        l_b = 'nan'
        l_bob = 'nan'
        l_bobk = 'nan'
        l_bobb = 'nan'
        
    d = {}
    d.update({'molecule': name})
    d.update({'point-dft': pt_e})
    d.update({'length-dft': l_e})
    d.update({'minE-dft': min_e})
    d.update({'point-ani2': pt_a})
    d.update({'length-ani2': l_a})
    d.update({'minE-ani2': min_a})
    d.update({'point-band': pt_b})
    d.update({'length-band': l_b})
    d.update({'minE-band': min_b})
    d.update({'point-bobrfr': pt_bob})
    d.update({'length-bobrfr': l_bob})
    d.update({'minE-bobrfr': min_bob})
    d.update({'point-bobkrr': pt_bobk})
    d.update({'length-bobkrr': l_bobk})
    d.update({'minE-bobkrr': min_bobk})
    d.update({'point-bobbrr': pt_bobb})
    d.update({'length-bobbrr': l_bobb})
    d.update({'minE-bobbrr': min_bobb})
    r0.append(d)

# %%
rdf = pd.DataFrame(r0, columns=['molecule', 
                                'point-dft', 'length-dft', 'minE-dft', 
                                'point-ani2', 'length-ani2', 'minE-ani2', 
                                'point-band', 'length-band', 'minE-band',
                                'point-bobrfr', 'length-bobrfr', 'minE-bobrfr',
                                'point-bobkrr', 'length-bobkrr', 'minE-bobkrr',
                                'point-bobbrr', 'length-bobbrr', 'minE-bobbrr'])
rdf
# Out:
#    molecule  point-dft  length-dft     minE-dft  point-ani2  length-ani2  \
# 0   C6H6_CC         10    1.402225 -6317.669985          10     1.402225
# 1   C6H6_CH          7    1.100826 -6317.659072           7     1.100826
# 2     CH3OH         10    1.415213 -3147.742536          10     1.415213
# 3       CH4          7    1.101130 -1102.089975           7     1.101130
# 4        CO          7    1.123672 -3082.362569          43     4.795346
# 5        H2          6    0.778000   -31.822850           6     0.778000
# 6    H2CCH2          9    1.317364 -2137.635190           9     1.317364
# 7       H2O          6    0.987265 -2078.540264           6     0.987265
# 8      HCCH          8    1.200373 -2103.297049           8     1.200373
# 9       HCN          8    1.159743 -2541.218017           8     1.159743
# 10       HF          5    0.921376 -2731.922910           5     0.921376
# 11       N2          7    1.102810 -2979.352985           7     1.102810
# 12      NH3          6    1.012117 -1538.225044           6     1.012117
#
#      minE-ani2 point-band length-band minE-band point-bobrfr length-bobrfr  \
# 0  -232.178529         10     1.40222  -1373.85            1       1.12487
# 1  -232.178278          7     1.10083   -1372.6            5        0.9907
# 2  -115.680312         10     1.41521  -506.726           44       4.89656
# 3   -40.499225          6     1.04354  -417.938           39        4.3863
# 4  -113.294154          1     1.00363  -158.118            8        1.1543
# 5    -1.129518          4       0.578  -107.315           16         1.778
# 6   -78.557024          9     1.31736  -559.205            9       1.31736
# 7   -76.387097          6    0.987265   -218.88           43       4.79498
# 8   -77.296977          7      1.1711  -400.481            8       1.20037
# 9   -93.393347          1     1.01603  -303.128           40       4.48876
# 10 -100.398622        nan         nan       nan          nan           nan
# 11 -109.498488         14     1.56848  -226.234           20       2.39913
# 12  -56.529278          6     1.01212  -283.738           21       2.54908
#
#    minE-bobrfr point-bobkrr length-bobkrr minE-bobkrr point-bobbrr  \
# 0     -233.389            5       1.21635    -119.238            7
# 1     -232.189            1      0.850537     -119.35            1
# 2     -117.932           11       1.48329    -115.682            9
# 3     -95.3904           45       4.99997    -40.5836           45
# 4     -168.477           45       4.99991     -113.42           45
# 5     -61.8603           45         4.678    -1.34954           45
# 6      -78.557            8       1.27617    -78.5634            1
# 7     -106.532           27       3.15691    -76.4364           45
# 8     -77.2961           44       4.89703    -77.3496           19
# 9      -125.85           45       5.00013    -93.7584           45
# 10         nan          nan           nan         nan          nan
# 11    -115.272            1      0.993851    -109.498            1
# 12    -58.8699           18       2.20413    -56.6204           18
#
#    length-bobbrr minE-bobbrr
# 0        1.27704    -119.204
# 1       0.850537    -119.435
# 2        1.35498    -115.687
# 3        4.99997     -40.587
# 4        4.99991    -113.743
# 5          4.678    -1.51938
# 6        1.09124    -78.5762
# 7        4.99958    -76.6452
# 8        2.26678    -77.2923
# 9        5.00013    -93.6233
# 10           nan         nan
# 11      0.993851    -109.509
# 12       2.20413    -56.5931

# %%
rdf.to_csv('data/r0.csv', index=False)

# %% [markdown]
# Find r<sub>0

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/data-all.csv')
df = df.fillna(np.nan)
df
# Out:
#         name  point bond    length        energy   ani2_energy  BAND_energy  \
# 0     C6H6-C      0   CC  0.884600  -6202.761889  -6206.252423  -968.374268
# 1     C6H6-C      1   CC  0.984600  -6259.129633  -6260.302569 -1012.032471
# 2     C6H6-C      2   CC  1.084600  -6290.919938  -6289.022412 -1110.447632
# 3     C6H6-C      3   CC  1.184600  -6307.793560  -6307.997541 -1222.968384
# 4     C6H6-C      4   CC  1.284600  -6315.569917  -6315.675317 -1319.632568
# ..       ...    ...  ...       ...           ...           ...          ...
# 776  gly-gly     41   NC  4.937205 -13387.905928 -13392.256556 -1614.245605
# 777  gly-gly     42   NC  5.037199 -13387.878640 -13392.258657 -1613.534058
# 778  gly-gly     43   NC  5.137189 -13387.852719 -13392.260095 -1613.468628
# 779  gly-gly     44   NC  5.237214 -13387.828043 -13392.260722 -1613.360474
# 780  gly-gly     45   NC  5.337273 -13387.804473 -13392.260034 -1613.256348
#
#      bobrfr_energy  bobkrr_energy  bobbrr_energy    mmff_energy   gaff_energy
# 0     -6322.749793   -6317.635291   -6319.055805    1830.471008   8439.631954
# 1     -6322.757063   -6320.096921   -6318.324263     967.973391   3420.359315
# 2     -6321.300860   -6320.702055   -6317.652787     458.862047   1548.954508
# 3     -6318.549316   -6320.226571   -6317.045847     181.276942    641.700866
# 4     -6317.382054   -6319.117238   -6316.485922      53.067576    178.685005
# ..             ...            ...            ...            ...           ...
# 776  -12364.615621  -13390.394251  -13390.518626  125947.279130  25838.914733
# 777  -12364.615621  -13390.333318  -13390.504379  141504.105351  27297.690196
# 778  -12364.615342  -13390.288034  -13390.507015  158464.458765  28796.420431
# 779  -12364.615342  -13390.217175  -13390.478211  176918.019394  30335.750334
# 780  -12364.615342  -13390.176394  -13390.482289  196950.768664  31915.643308
#
# [781 rows x 12 columns]

# %%
names = np.unique(df['name'])
names
# Out:
# array(['C6H6-C', 'C6H6-H', 'CH3OH', 'CH4', 'CO', 'H2', 'H2CCH2', 'H2O',
#        'HCCH', 'HCN', 'HF', 'N2', 'NH3', 'ala-ala', 'aspartame',
#        'biphenyl', 'gly-gly'], dtype=object)

# %%
r0 = []
for name in names:
    ndf = df[df['name'] == name]
    min_e = min(ndf['energy'])
    min_a = min(ndf['ani2_energy'])
    if name == 'CO':
        # CO goes down after 2.5 angstroms 
        min_a = min(ndf['ani2_energy'][:15])
    min_gaff = min(ndf['gaff_energy'][:10])
    
    if name == 'HF':
        min_b = 'nan'
#         min_fchl = 'nan'
        min_bob = 'nan'
        min_bobk = 'nan'
        min_bobb = 'nan'
        min_mmff = min(ndf['mmff_energy'][:8])
    elif name == 'sucrose':
        min_b = 'nan'
#         min_fchl = min(ndf['fchl_energy'])
        min_bob = min(ndf['bobrfr_energy'])
        min_bobk = min(ndf['bobkrr_energy'])
        min_bobb = min(ndf['bobbrr_energy'])
        min_mmff = min(ndf['mmff_energy'][:9])
    else:
        min_b = min(ndf['BAND_energy'].dropna())
#         min_fchl = min(ndf['fchl_energy'])
        min_bob = min(ndf['bobrfr_energy'])
        min_bobk = min(ndf['bobkrr_energy'])
        min_bobb = min(ndf['bobbrr_energy'])
        min_mmff = min(ndf['mmff_energy'][:9])
    
    pt_e = ndf.loc[df['energy'] == min_e, 'point'].iloc[0]
    pt_a = ndf.loc[df['ani2_energy'] == min_a, 'point'].iloc[0]
    pt_mmff = ndf.loc[df['mmff_energy'] == min_mmff, 'point'].iloc[0]
    pt_gaff = ndf.loc[df['gaff_energy'] == min_gaff, 'point'].iloc[0]
    if name == 'HF':
        pt_b = 'nan'
#         pt_fchl = 'nan'
        pt_bob = 'nan'
        pt_bobk = 'nan'
        pt_bobb = 'nan'
    elif name == 'sucrose':
        pt_b = 'nan'
#         pt_fchl = ndf.loc[df['fchl_energy'] == min_fchl, 'point'].iloc[0]
        pt_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'point'].iloc[0]
        pt_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'point'].iloc[0]
        pt_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'point'].iloc[0]
    else:
        pt_b = ndf.loc[df['BAND_energy'] == min_b, 'point'].iloc[0]
#         pt_fchl = ndf.loc[df['fchl_energy'] == min_fchl, 'point'].iloc[0]
        pt_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'point'].iloc[0]
        pt_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'point'].iloc[0]
        pt_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'point'].iloc[0]

    l_e = ndf.loc[df['energy'] == min_e, 'length'].iloc[0]
    l_a = ndf.loc[df['ani2_energy'] == min_a, 'length'].iloc[0]
    l_mmff = ndf.loc[df['mmff_energy'] == min_mmff, 'length'].iloc[0]
    l_gaff = ndf.loc[df['gaff_energy'] == min_gaff, 'length'].iloc[0]
    if name == 'HF':
        l_b = 'nan'
#         l_fchl = 'nan'
        l_bob = 'nan'
        l_bobk = 'nan'
        l_bobb = 'nan'
    elif name == 'sucrose':
        l_b = 'nan'
#         l_fchl = ndf.loc[df['fchl_energy'] == min_fchl, 'length'].iloc[0]
        l_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'length'].iloc[0]
        l_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'length'].iloc[0]
        l_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'length'].iloc[0]
    else:
        l_b = ndf.loc[df['BAND_energy'] == min_b, 'length'].iloc[0]
#         l_fchl = ndf.loc[df['fchl_energy'] == min_fchl, 'length'].iloc[0]
        l_bob = ndf.loc[df['bobrfr_energy'] == min_bob, 'length'].iloc[0]
        l_bobk = ndf.loc[df['bobkrr_energy'] == min_bobk, 'length'].iloc[0]
        l_bobb = ndf.loc[df['bobbrr_energy'] == min_bobb, 'length'].iloc[0]
        
    d = {}
    d.update({'molecule': name})
    d.update({'point-dft': pt_e})
    d.update({'length-dft': l_e})
    d.update({'minE-dft': min_e})
    d.update({'point-ani2': pt_a})
    d.update({'length-ani2': l_a})
    d.update({'minE-ani2': min_a})
    d.update({'point-band': pt_b})
    d.update({'length-band': l_b})
    d.update({'minE-band': min_b})
#     d.update({'point-fchl': pt_fchl})
#     d.update({'length-fchl': l_fchl})
#     d.update({'minE-fchl': min_fchl})
    d.update({'point-bobrfr': pt_bob})
    d.update({'length-bobrfr': l_bob})
    d.update({'minE-bobrfr': min_bob})
    d.update({'point-bobkrr': pt_bobk})
    d.update({'length-bobkrr': l_bobk})
    d.update({'minE-bobkrr': min_bobk})
    d.update({'point-bobbrr': pt_bobb})
    d.update({'length-bobbrr': l_bobb})
    d.update({'minE-bobbrr': min_bobb})
    d.update({'point-mmff': pt_mmff})
    d.update({'length-mmff': l_mmff})
    d.update({'minE-mmff': min_mmff})
    d.update({'point-gaff': pt_gaff})
    d.update({'length-gaff': l_gaff})
    d.update({'minE-gaff': min_gaff})
    r0.append(d)

# %%
rdf = pd.DataFrame(r0, columns=['molecule', 
                                'point-dft', 'length-dft', 'minE-dft', 
                                'point-ani2', 'length-ani2', 'minE-ani2', 
                                'point-band', 'length-band', 'minE-band',
#                                 'point-fchl', 'length-fchl', 'minE-fchl',
                                'point-bobrfr', 'length-bobrfr', 'minE-bobrfr',
                                'point-bobkrr', 'length-bobkrr', 'minE-bobkrr',
                                'point-bobbrr', 'length-bobbrr', 'minE-bobbrr',
                                'point-mmff', 'length-mmff', 'minE-mmff',
                                'point-gaff', 'length-gaff', 'minE-gaff'])
rdf
# Out:
#      molecule  point-dft  length-dft      minE-dft  point-ani2  length-ani2  \
# 0      C6H6-C          5    1.384600  -6317.796290           5     1.384600
# 1      C6H6-H          5    1.080490  -6317.796291           5     1.080490
# 2       CH3OH          5    1.406200  -3147.771121           5     1.406200
# 3         CH4          5    1.082200  -1102.023782           5     1.082200
# 4          CO          5    1.127100  -3082.492964           5     1.127100
# 5          H2          5    0.776600    -31.749980           5     0.776600
# 6      H2CCH2          5    1.316300  -2137.610367           5     1.316300
# 7         H2O          5    0.959200  -2078.579646           5     0.959200
# 8        HCCH          5    1.193700  -2103.310860           5     1.193700
# 9         HCN          5    1.137500  -2541.292611           5     1.137500
# 10         HF          5    0.932400  -2731.946285           5     0.932400
# 11         N2          5    1.098200  -2979.523223           5     1.098200
# 12        NH3          5    1.012600  -1538.210649           5     1.012600
# 13    ala-ala          5    1.335374 -15535.840692           5     1.335374
# 14  aspartame          5    1.342729 -28020.594581           5     1.342729
# 15   biphenyl          5    1.471085 -12603.427537           5     1.471085
# 16    gly-gly          5    1.337212 -13396.572572           5     1.337212
#
#        minE-ani2 point-band length-band minE-band  ... minE-bobkrr  \
# 0   -6317.909650          5      1.3846  -1372.76  ...     -6320.7
# 1   -6317.909650          5     1.08049  -1372.76  ...    -6317.85
# 2   -3147.823690          5      1.4062  -506.988  ...    -3143.47
# 3   -1102.038219          5      1.0822  -418.106  ...    -1104.18
# 4   -3082.539701          0      0.6271  -185.247  ...    -3089.57
# 5     -30.731869          3      0.5769  -106.992  ...    -66.2559
# 6   -2137.645485          5      1.3163  -559.355  ...    -2137.21
# 7   -2078.624807          5      0.9592  -219.454  ...    -2087.04
# 8   -2103.355768          5      1.1937  -400.345  ...     -2102.4
# 9   -2541.349860          0      0.6375  -307.321  ...    -2550.72
# 10  -2731.988441        nan         nan       nan  ...         nan
# 11  -2979.606018          0      0.5982  -227.874  ...    -2979.01
# 12  -1538.241031          0      0.5126  -291.891  ...    -1545.25
# 13 -15536.073587          5     1.33537  -2316.17  ...    -15535.2
# 14 -28020.907632          5     1.34273  -4254.67  ...    -19729.5
# 15 -12603.625341          5     1.47109   -2628.1  ...    -8454.64
# 16 -13396.734711          5     1.33721  -1717.41  ...    -13394.2
#
#    point-bobbrr length-bobbrr minE-bobbrr point-mmff length-mmff   minE-mmff  \
# 0             0        0.8846    -6319.06          5    1.384600   16.575675
# 1            10       1.58057    -6316.44          5    1.080490   16.575675
# 2            20        2.9062    -3142.82          5    1.406200    1.077657
# 3            45        5.0822    -1103.03          5    1.082200    0.167136
# 4            45        5.1271    -3086.73          6    1.227100    0.823775
# 5            45         4.772    -23.9464          0    0.277200    0.000000
# 6             7        1.5163    -2134.66          5    1.316300    8.641677
# 7            45        4.9592    -2075.41          5    0.959200    0.232217
# 8            45        5.1937    -2104.25          5    1.193700  164.337949
# 9            44        5.0375    -2543.95          5    1.137500    0.650222
# 10          nan           nan         nan          5    0.932400    0.031521
# 11           45        5.0982    -2968.07          8    1.398200    0.116624
# 12            0        0.5126     -1539.4          5    1.012600    0.136011
# 13           13       2.13532    -15530.4          5    1.335374   27.020023
# 14           30        3.8427    -19753.1          5    1.342729   41.334214
# 15            4        1.3711    -8461.72          5    1.471085   41.018242
# 16            6       1.43721    -13391.7          5    1.337212   23.623478
#
#    point-gaff length-gaff    minE-gaff
# 0           5    1.384600    19.456137
# 1           5    1.080490    19.456137
# 2           5    1.406200    11.175286
# 3           5    1.082200     0.922327
# 4           6    1.227100     0.465586
# 5           8    1.076300     1.175842
# 6           5    1.316300     4.193630
# 7           6    1.059200     6.969755
# 8           5    1.193700  3643.998149
# 9           5    1.137500     0.183724
# 10          7    1.132400     2.197568
# 11          5    1.098200     3.404758
# 12          5    1.012600     0.190823
# 13          5    1.335374   -17.581818
# 14          5    1.342729     0.959101
# 15          5    1.471085    52.647093
# 16          5    1.337212   -10.934337
#
# [17 rows x 25 columns]

# %%
rdf.to_csv('data/r0.csv', index=False)
